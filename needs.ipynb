# %%
# my-ollama-chatbot/
# │
# ├── app.py                  # 🎨 Streamlit UI (main entry point)
# │
# ├── ollama_client.py        # 🤖 الاتصال بـ Llama3 (Ollama API)
# │
# ├── pdf_handler.py          # 📄 تحميل + قراءة + تقسيم PDF
# │
# ├── prompts.py              # 🧠 system prompts (Study assistant prompt)
# │
# ├── utils.py                # ⚙️ helper functions (build prompt, formatting)
# │
# ├── requirements.txt        # 📦 dependencies
# │
# ├── .venv/                  # 🧪 virtual environment (مش بنعدله)
# │
# └── data/
#     └── uploads/           # 📂 ملفات PDF المؤقتة (اختياري)

# %%
# PDF → chunks → embeddings → FAISS DB
#                          ↓
#                 question → search top chunks
#                          ↓
#                  context → LLM (Llama3)

# %%
# User Question
#       ↓
# Agent Router (decides)
#       ↓
#  ┌───────────────┐
#  │               │
# RAG            General LLM
#  │               │
# FAISS         Ollama direct
#  │               │
#  └──────→ Answer ←──────┘

# %%
# !pip install langchain-huggingface

# %%
# streamlit run chat_bot_app.py

# %%
# venv\Scripts\activate.bat
